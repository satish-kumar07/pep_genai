# %% [markdown]
# #### Regression:
#
# ``y = mx+c``
#
# 1. Columns = Features
# 2. Rows = data points
#
# y = Target[feature which are going to predict]
#
#     independent variable = x[Features]
#
#     dependent variable = y[Target]
#
# Regression Cndition:
# 1. Target should be continuous numeric values
# 2. Their should be atleast one independent variable on which are dependent variable[Target] depends
# ```
# y= w1x1 + w2x2 + w3x3 + b
# ```

# %% [markdown]
# #### Code Implemention
#
# 1. Library Use
#     Scikit-Learn => For model selection
#
#     matplotlib => Data Visualization
#
#     pandas, Numpy - data manipulation, transformation/cleaning
#
#
# 2. Steps
#     1. Data Collections
#     2. Data Preprocessing
#         1. data cleaning, Data Transformation
#         2. EDA
#         3. Removing Duplicates
#         4. Handling Missing value
#             1. Data Imputation - replace NUll values
#             2. Data cleaing - Removing the row
#         5. Feature Engineering
#
#     3. Define the feature[x] and Target[y]
#     4. split the data into training set and testing set
#
#             x-train,x-test
#
#             y-train,y-test
#
#     5. Train the model on triaing set ```X-train```,```Y-train```
#     6. Predic the values from the model with the help og testing set as input
#
#             [predict(X_test)] y_pred
#
#     7. Compare the predicted value (y_pred) to the actual value(y_test) to find out the accuracy of the model.
